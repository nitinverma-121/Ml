# %%
import pandas as pd
from pandas import DataFrame
from sklearn import datasets
import matplotlib.pyplot as ptr
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn import tree
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier

# %%
cancer_data= datasets.load_breast_cancer()

features= DataFrame(data= cancer_data.data, columns= cancer_data.feature_names)

features['target']= cancer_data.target

# %%
#visualize
d0= features[features.target==0]
d1= features[features.target==1]

ptr.figure(figsize=(14, 10))

ptr.xlabel('mean texture', fontsize= 16)
ptr.ylabel('mean perimeter', fontsize= 16)

ptr.title('Cancer Data Set \n', fontsize= 20)

ptr.scatter(d0['mean texture'], d0['mean perimeter'], color= "red")
ptr.scatter(d1['mean texture'], d1['mean perimeter'], color= "green")

ptr.legend(['malignant', 'benign'])

ptr.show()

# %%
target= features['target']
del features['target']

# %%
cross_val_score(LogisticRegression(max_iter=3000), features, target, cv= 3)
# Out:
# array([0.94210526, 0.96315789, 0.94708995])

# %%
cross_val_score(tree.DecisionTreeClassifier(max_depth= 10, criterion= 'entropy'), features, target, cv= 3)
# Out:
# array([0.88421053, 0.94210526, 0.9047619 ])

# %%
cross_val_score(svm.SVC(C= 30, gamma= 0.00001), features, target, cv= 3)
# Out:
# array([0.91052632, 0.95789474, 0.94179894])

# %%
cross_val_score(RandomForestClassifier(n_estimators= 30,), features, target, cv= 3)
# Out:
# array([0.94736842, 0.96842105, 0.95238095])
